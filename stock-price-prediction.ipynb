# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("GOOG")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-08-19 00:00:00-04:00    2.487833    2.588839    2.387325    2.496292
# 2004-08-20 00:00:00-04:00    2.512960    2.713729    2.500273    2.694573
# 2004-08-23 00:00:00-04:00    2.755276    2.823193    2.712983    2.721690
# 2004-08-24 00:00:00-04:00    2.767466    2.776422    2.576649    2.608991
# 2004-08-25 00:00:00-04:00    2.611230    2.686860    2.584361    2.637103
# ...                               ...         ...         ...         ...
# 2024-06-14 00:00:00-04:00  175.852005  178.729996  175.852005  178.369995
# 2024-06-17 00:00:00-04:00  176.979996  179.919998  176.490005  178.779999
# 2024-06-18 00:00:00-04:00  178.789993  178.910004  175.619995  176.449997
# 2024-06-20 00:00:00-04:00  176.710007  178.740005  176.460007  177.710007
# 2024-06-21 00:00:00-04:00  178.490005  182.511993  178.059998  180.259995
#
#                               Volume  Dividends  Stock Splits
# Date
# 2004-08-19 00:00:00-04:00  897427216        0.0           0.0
# 2004-08-20 00:00:00-04:00  458857488        0.0           0.0
# 2004-08-23 00:00:00-04:00  366857939        0.0           0.0
# 2004-08-24 00:00:00-04:00  306396159        0.0           0.0
# 2004-08-25 00:00:00-04:00  184645512        0.0           0.0
# ...                              ...        ...           ...
# 2024-06-14 00:00:00-04:00   12361600        0.0           0.0
# 2024-06-17 00:00:00-04:00   15272900        0.0           0.0
# 2024-06-18 00:00:00-04:00   15640300        0.0           0.0
# 2024-06-20 00:00:00-04:00   16753200        0.0           0.0
# 2024-06-21 00:00:00-04:00   58903200        0.0           0.0
#
# [4994 rows x 7 columns]

# %%
sp500.index
# Out:
# DatetimeIndex(['2004-08-19 00:00:00-04:00', '2004-08-20 00:00:00-04:00',
#                '2004-08-23 00:00:00-04:00', '2004-08-24 00:00:00-04:00',
#                '2004-08-25 00:00:00-04:00', '2004-08-26 00:00:00-04:00',
#                '2004-08-27 00:00:00-04:00', '2004-08-30 00:00:00-04:00',
#                '2004-08-31 00:00:00-04:00', '2004-09-01 00:00:00-04:00',
#                ...
#                '2024-06-07 00:00:00-04:00', '2024-06-10 00:00:00-04:00',
#                '2024-06-11 00:00:00-04:00', '2024-06-12 00:00:00-04:00',
#                '2024-06-13 00:00:00-04:00', '2024-06-14 00:00:00-04:00',
#                '2024-06-17 00:00:00-04:00', '2024-06-18 00:00:00-04:00',
#                '2024-06-20 00:00:00-04:00', '2024-06-21 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=4994, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-08-19 00:00:00-04:00    2.487833    2.588839    2.387325    2.496292
# 2004-08-20 00:00:00-04:00    2.512960    2.713729    2.500273    2.694573
# 2004-08-23 00:00:00-04:00    2.755276    2.823193    2.712983    2.721690
# 2004-08-24 00:00:00-04:00    2.767466    2.776422    2.576649    2.608991
# 2004-08-25 00:00:00-04:00    2.611230    2.686860    2.584361    2.637103
# ...                               ...         ...         ...         ...
rows x 7 columns]

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-08-19 00:00:00-04:00    2.487833    2.588839    2.387325    2.496292
# 2004-08-20 00:00:00-04:00    2.512960    2.713729    2.500273    2.694573
# 2004-08-23 00:00:00-04:00    2.755276    2.823193    2.712983    2.721690
# 2004-08-24 00:00:00-04:00    2.767466    2.776422    2.576649    2.608991
# 2004-08-25 00:00:00-04:00    2.611230    2.686860    2.584361    2.637103
# ...                               ...         ...         ...         ...
# 2024-06-14 00:00:00-04:00  175.852005  178.729996  175.852005  178.369995
# 2024-06-17 00:00:00-04:00  176.979996  179.919998  176.490005  178.779999
# 2024-06-18 00:00:00-04:00  178.789993  178.910004  175.619995  176.449997
# 2024-06-20 00:00:00-04:00  176.710007  178.740005  176.460007  177.710007
# 2024-06-21 00:00:00-04:00  178.490005  182.511993  178.059998  180.259995
#
#                               Volume    Tomorrow  Target
# Date
# 2004-08-19 00:00:00-04:00  897427216    2.694573       1
# 2004-08-20 00:00:00-04:00  458857488    2.721690       1
# 2004-08-23 00:00:00-04:00  366857939    2.608991       0
# 2004-08-24 00:00:00-04:00  306396159    2.637103       1
# 2004-08-25 00:00:00-04:00  184645512    2.684621       1
# ...                              ...         ...     ...
# 2024-06-14 00:00:00-04:00   12361600  178.779999       1
# 2024-06-17 00:00:00-04:00   15272900  176.449997       0
# 2024-06-18 00:00:00-04:00   15640300  177.710007       1
# 2024-06-20 00:00:00-04:00   16753200  180.259995       1
# 2024-06-21 00:00:00-04:00   58903200         NaN       0
#
# [4994 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6666666666666666

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=1500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    1943
# 1    1551
# Name: count, dtype: int64

# %%
precision_score(test["Target"], predictions["Predictions"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 precision_score(test["Target"], predictions["Predictions"])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:2190, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2023 @validate_params(
#    2024     {
#    2025         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2050     zero_division="warn",
#    2051 ):
#    2052     """Compute the precision.
#    2053
#    2054     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2188     array([0.5, 1. , 1. ])
#    2189     """
# -> 2190     p, _, _, _ = precision_recall_fscore_support(
#    2191         y_true,
#    2192         y_pred,
#    2193         labels=labels,
#    2194         pos_label=pos_label,
#    2195         average=average,
#    2196         warn_for=("precision",),
#    2197         sample_weight=sample_weight,
#    2198         zero_division=zero_division,
#    2199     )
#    2200     return p
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1775, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1612 """Compute precision, recall, F-measure and support for each class.
#    1613
#    1614 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1772  array([2, 2, 2]))
#    1773 """
#    1774 _check_zero_division(zero_division)
# -> 1775 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1777 # Calculate tp_sum, pred_sum, true_sum ###
#    1778 samplewise = average == "samples"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1547, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1544 if average not in average_options and average != "binary":
#    1545     raise ValueError("average has to be one of " + str(average_options))
# -> 1547 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1548 # Convert to Python primitive type to avoid NumPy type / Python str
#    1549 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1550 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:99, in _check_targets(y_true, y_pred)
#      72 def _check_targets(y_true, y_pred):
#      73     """Check that y_true and y_pred belong to the same classification task.
#      74
#      75     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      97     y_pred : array or indicator matrix
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     type_true = type_of_target(y_true, input_name="y_true")
#     101     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:460, in check_consistent_length(*arrays)
#     458 uniques = np.unique(lengths)
#     459 if len(uniques) > 1:
# --> 460     raise ValueError(
#     461         "Found input variables with inconsistent numbers of samples: %r"
#     462         % [int(l) for l in lengths]
#     463     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [100, 3494]

# %%
predictions["Target"].value_counts() / predictions.shape[0]
